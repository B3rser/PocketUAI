# %% [markdown]
# # Apriori algorithm

# %%
import pandas as pd
from apyori import apriori

# %%
df = pd.read_csv('spending-grouped-newclasses.csv')
df.head()
# Out:
#    housing  food  transportation  income  non-essential  health  university  \
# 0      709   296             123    1228            435     205  494.916667
# 1      557   365              85    1881            620     221  409.000000
# 2      666   220             137    1662            601     135  254.250000
# 3      652   289             114     882            540     135  411.250000
# 4      825   372             168    1332            434     142  323.916667
#
#    Class
# 0      6
# 1      6
# 2      4
# 3      6
# 4      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   housing         996 non-null    int64
#  1   food            996 non-null    int64
#  2   transportation  996 non-null    int64
#  3   income          996 non-null    int64
#  4   non-essential   996 non-null    int64
#  5   health          996 non-null    int64
#  6   university      996 non-null    float64
#  7   Class           996 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 62.4 KB

# %%
def convert_to_cat(df, num_rangos):
    df_cat = df.copy()
    
    for col in df_cat.select_dtypes(include=['float64', 'int64']).columns:
        if col == "Class":
            df_cat[col] = df_cat[col].astype(str)
            df_cat[col] = df_cat[col].apply(lambda x: f"{col} / {x}")
        else:
            intervalos = pd.cut(df_cat[col], bins=num_rangos)
            df_cat[col] = intervalos.apply(
                lambda x: f"{col} / {x.left}-{x.right}" if pd.notnull(x) else x
            )
    
    return df_cat

# %%
df_t = convert_to_cat(df, 5); 
df_t.head()
# Out:
#                  housing                food                transportation  \
# 0  housing / 640.6-760.4  food / 280.0-340.0  transportation / 110.0-140.0
# 1  housing / 520.8-640.6  food / 340.0-400.0   transportation / 80.0-110.0
# 2  housing / 640.6-760.4  food / 160.0-220.0  transportation / 110.0-140.0
# 3  housing / 640.6-760.4  food / 280.0-340.0  transportation / 110.0-140.0
# 4  housing / 760.4-880.2  food / 340.0-400.0  transportation / 140.0-170.0
#
#                    income                non-essential                health  \
# 0   income / 947.0-1334.0  non-essential / 361.0-490.0  health / 199.6-248.8
# 1  income / 1721.0-2108.0  non-essential / 619.0-748.0  health / 199.6-248.8
# 2  income / 1334.0-1721.0  non-essential / 490.0-619.0  health / 101.2-150.4
# 3  income / 558.065-947.0  non-essential / 490.0-619.0  health / 101.2-150.4
# 4   income / 947.0-1334.0  non-essential / 361.0-490.0  health / 101.2-150.4
#
#                   university      Class
# 0  university / 450.05-500.0  Class / 6
# 1  university / 400.1-450.05  Class / 6
# 2   university / 250.0-300.2  Class / 4
# 3  university / 400.1-450.05  Class / 6
# 4  university / 300.2-350.15  Class / 5

# %%
transactions = df_t.values.tolist()
transactions
# Out:
# [['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 231.355-361.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 4'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 350.15-400.1',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 231.355-361.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 558.065-947.0',
#   'non-essential / 748.0-877.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 558.065-947.0',
#   'non-essential / 748.0-877.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 4'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 51.754-101.2',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 170.0-200.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 248.8-298.0',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 619.0-748.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 248.8-298.0',
#   'university / 400.1-450.05',
#   'Class / 3'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 51.754-101.2',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
# ...
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 350.15-400.1',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 558.065-947.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 1'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 170.0-200.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 248.8-298.0',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 558.065-947.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 1'],
#  ['housing / 640.6-760.4',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 558.065-947.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 6'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 51.754-101.2',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 880.2-1000.0',
#   'food / 160.0-220.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 99.7-160.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 3'],
#  ['housing / 880.2-1000.0',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 450.05-500.0',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 140.0-170.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 558.065-947.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 80.0-110.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 51.754-101.2',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 248.8-298.0',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 2108.0-2495.0',
#   'non-essential / 361.0-490.0',
#   'health / 150.4-199.6',
#   'university / 450.05-500.0',
#   'Class / 3'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 80.0-110.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 748.0-877.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 340.0-400.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 248.8-298.0',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 880.2-1000.0',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 558.065-947.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 400.1-450.05',
#   'Class / 1'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 490.0-619.0',
#   'health / 199.6-248.8',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 400.1-450.05',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 558.065-947.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 760.4-880.2',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 748.0-877.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 160.0-220.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 99.7-160.0',
#   'transportation / 80.0-110.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 2'],
#  ['housing / 640.6-760.4',
#   'food / 160.0-220.0',
#   'transportation / 140.0-170.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 350.15-400.1',
#   'Class / 3'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 947.0-1334.0',
#   'non-essential / 748.0-877.0',
#   'health / 51.754-101.2',
#   'university / 350.15-400.1',
#   'Class / 4'],
#  ['housing / 760.4-880.2',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 361.0-490.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 400.401-520.8',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 619.0-748.0',
#   'health / 51.754-101.2',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 99.7-160.0',
#   'transportation / 49.85-80.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 231.355-361.0',
#   'health / 199.6-248.8',
#   'university / 250.0-300.2',
#   'Class / 2'],
#  ['housing / 400.401-520.8',
#   'food / 340.0-400.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 640.6-760.4',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 340.0-400.0',
#   'transportation / 49.85-80.0',
#   'income / 947.0-1334.0',
#   'non-essential / 231.355-361.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6'],
#  ['housing / 880.2-1000.0',
#   'food / 99.7-160.0',
#   'transportation / 170.0-200.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 300.2-350.15',
#   'Class / 1'],
#  ['housing / 400.401-520.8',
#   'food / 220.0-280.0',
#   'transportation / 49.85-80.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 619.0-748.0',
#   'health / 150.4-199.6',
#   'university / 250.0-300.2',
#   'Class / 4'],
#  ['housing / 640.6-760.4',
#   'food / 280.0-340.0',
#   'transportation / 110.0-140.0',
#   'income / 1334.0-1721.0',
#   'non-essential / 490.0-619.0',
#   'health / 101.2-150.4',
#   'university / 250.0-300.2',
#   'Class / 5'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 110.0-140.0',
#   'income / 1721.0-2108.0',
#   'non-essential / 490.0-619.0',
#   'health / 150.4-199.6',
#   'university / 300.2-350.15',
#   'Class / 4'],
#  ['housing / 520.8-640.6',
#   'food / 220.0-280.0',
#   'transportation / 170.0-200.0',
#   'income / 947.0-1334.0',
#   'non-essential / 748.0-877.0',
#   'health / 101.2-150.4',
#   'university / 450.05-500.0',
#   'Class / 6']]

# %%
rules = apriori(transactions = transactions, min_support = 0.01, min_cinfidence = 0.2, min_lift = 3, min_length = 2, max_length = 4)

# %%
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'housing / 760.4-880.2', 'Class / 1', 'food / 160.0-220.0'}), support=0.02108433734939759, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 760.4-880.2', 'food / 160.0-220.0'}), confidence=0.1381578947368421, lift=3.440131578947368), OrderedStatistic(items_base=frozenset({'housing / 760.4-880.2', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5249999999999999, lift=3.4401315789473674)]),
#  RelationRecord(items=frozenset({'housing / 880.2-1000.0', 'Class / 1', 'food / 160.0-220.0'}), support=0.01706827309236948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 880.2-1000.0', 'food / 160.0-220.0'}), confidence=0.1118421052631579, lift=3.1827067669172933), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 1'}), confidence=0.4857142857142857, lift=3.182706766917293)]),
#  RelationRecord(items=frozenset({'transportation / 110.0-140.0', 'Class / 1', 'food / 160.0-220.0'}), support=0.02108433734939759, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'transportation / 110.0-140.0', 'food / 160.0-220.0'}), confidence=0.1381578947368421, lift=3.0578947368421048), OrderedStatistic(items_base=frozenset({'food / 160.0-220.0'}), items_add=frozenset({'transportation / 110.0-140.0', 'Class / 1'}), confidence=0.1160220994475138, lift=3.0410002907822036), OrderedStatistic(items_base=frozenset({'transportation / 110.0-140.0', 'Class / 1'}), items_add=frozenset({'food / 160.0-220.0'}), confidence=0.5526315789473684, lift=3.0410002907822036), OrderedStatistic(items_base=frozenset({'transportation / 110.0-140.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 1'}), confidence=0.4666666666666666, lift=3.0578947368421048)]),
#  RelationRecord(items=frozenset({'transportation / 170.0-200.0', 'Class / 1', 'food / 160.0-220.0'}), support=0.015060240963855422, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'transportation / 170.0-200.0', 'food / 160.0-220.0'}), confidence=0.09868421052631578, lift=3.5103383458646613), OrderedStatistic(items_base=frozenset({'transportation / 170.0-200.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5357142857142857, lift=3.5103383458646613)]),
#  RelationRecord(items=frozenset({'Class / 1', 'university / 450.05-500.0', 'food / 160.0-220.0'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 160.0-220.0', 'university / 450.05-500.0'}), confidence=0.10526315789473682, lift=3.1770334928229658), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 1'}), confidence=0.48484848484848475, lift=3.1770334928229658)]),
#  RelationRecord(items=frozenset({'food / 220.0-280.0', 'housing / 880.2-1000.0', 'Class / 1'}), support=0.014056224899598393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 220.0-280.0', 'housing / 880.2-1000.0'}), confidence=0.09210526315789473, lift=3.1633393829401086), OrderedStatistic(items_base=frozenset({'food / 220.0-280.0', 'housing / 880.2-1000.0'}), items_add=frozenset({'Class / 1'}), confidence=0.48275862068965514, lift=3.1633393829401086)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'housing / 760.4-880.2', 'Class / 1'}), support=0.025100401606425703, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 99.7-160.0', 'housing / 760.4-880.2'}), confidence=0.1644736842105263, lift=3.090863952333664), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'housing / 760.4-880.2'}), items_add=frozenset({'Class / 1'}), confidence=0.4716981132075471, lift=3.0908639523336636)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'housing / 880.2-1000.0', 'Class / 1'}), support=0.018072289156626505, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 99.7-160.0', 'housing / 880.2-1000.0'}), confidence=0.11842105263157894, lift=3.931578947368421), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'housing / 880.2-1000.0'}), items_add=frozenset({'Class / 1'}), confidence=0.6, lift=3.9315789473684206)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'transportation / 140.0-170.0', 'Class / 1'}), support=0.02610441767068273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 99.7-160.0', 'transportation / 140.0-170.0'}), confidence=0.17105263157894735, lift=3.7036613272311207), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'transportation / 140.0-170.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5652173913043478, lift=3.7036613272311207)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0', 'Class / 1'}), support=0.02208835341365462, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0'}), confidence=0.14473684210526316, lift=3.067189249720045), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 1'}), confidence=0.4680851063829788, lift=3.067189249720045)]),
#  RelationRecord(items=frozenset({'housing / 760.4-880.2', 'transportation / 140.0-170.0', 'Class / 1'}), support=0.024096385542168676, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 760.4-880.2', 'transportation / 140.0-170.0'}), confidence=0.15789473684210525, lift=3.931578947368421), OrderedStatistic(items_base=frozenset({'housing / 760.4-880.2', 'transportation / 140.0-170.0'}), items_add=frozenset({'Class / 1'}), confidence=0.6000000000000001, lift=3.9315789473684215)]),
#  RelationRecord(items=frozenset({'housing / 760.4-880.2', 'transportation / 170.0-200.0', 'Class / 1'}), support=0.023092369477911646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 760.4-880.2', 'transportation / 170.0-200.0'}), confidence=0.15131578947368418, lift=3.5048959608323123), OrderedStatistic(items_base=frozenset({'housing / 760.4-880.2', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5348837209302325, lift=3.5048959608323127)]),
#  RelationRecord(items=frozenset({'transportation / 170.0-200.0', 'housing / 880.2-1000.0', 'Class / 1'}), support=0.020080321285140562, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 880.2-1000.0', 'transportation / 170.0-200.0'}), confidence=0.13157894736842105, lift=3.6403508771929824), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5555555555555556, lift=3.6403508771929824)]),
#  RelationRecord(items=frozenset({'university / 400.1-450.05', 'housing / 880.2-1000.0', 'Class / 1'}), support=0.014056224899598393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'university / 400.1-450.05', 'housing / 880.2-1000.0'}), confidence=0.09210526315789473, lift=3.52834008097166), OrderedStatistic(items_base=frozenset({'university / 400.1-450.05', 'housing / 880.2-1000.0'}), items_add=frozenset({'Class / 1'}), confidence=0.5384615384615384, lift=3.5283400809716596)]),
#  RelationRecord(items=frozenset({'housing / 880.2-1000.0', 'Class / 1', 'university / 450.05-500.0'}), support=0.01706827309236948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'housing / 880.2-1000.0', 'university / 450.05-500.0'}), confidence=0.1118421052631579, lift=3.094298245614035), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 1'}), confidence=0.47222222222222227, lift=3.094298245614035)]),
#  RelationRecord(items=frozenset({'transportation / 170.0-200.0', 'income / 558.065-947.0', 'Class / 1'}), support=0.013052208835341365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 1'}), items_add=frozenset({'income / 558.065-947.0', 'transportation / 170.0-200.0'}), confidence=0.08552631578947367, lift=4.48337950138504), OrderedStatistic(items_base=frozenset({'transportation / 170.0-200.0'}), items_add=frozenset({'income / 558.065-947.0', 'Class / 1'}), confidence=0.06701030927835051, lift=3.1782032400589104), OrderedStatistic(items_base=frozenset({'income / 558.065-947.0', 'Class / 1'}), items_add=frozenset({'transportation / 170.0-200.0'}), confidence=0.6190476190476191, lift=3.17820324005891), OrderedStatistic(items_base=frozenset({'income / 558.065-947.0', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 1'}), confidence=0.6842105263157894, lift=4.48337950138504)]),
#  RelationRecord(items=frozenset({'food / 160.0-220.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.03112449799196787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'food / 160.0-220.0'}), confidence=0.155, lift=4.540588235294117), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 2'}), confidence=0.9117647058823528, lift=4.540588235294117)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'food / 160.0-220.0', 'Class / 2'}), support=0.03112449799196787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 80.0-110.0', 'food / 160.0-220.0'}), confidence=0.155, lift=3.4306666666666668), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6888888888888889, lift=3.4306666666666668)]),
#  RelationRecord(items=frozenset({'food / 220.0-280.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.02610441767068273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'food / 220.0-280.0', 'transportation / 49.85-80.0'}), confidence=0.13, lift=3.158048780487805), OrderedStatistic(items_base=frozenset({'food / 220.0-280.0', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6341463414634146, lift=3.158048780487805)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.04718875502008032, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'food / 99.7-160.0', 'transportation / 49.85-80.0'}), confidence=0.235, lift=4.98), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'food / 99.7-160.0', 'Class / 2'}), confidence=0.23618090452261306, lift=3.0550153364223713), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.6103896103896104, lift=3.0550153364223718), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=1.0, lift=4.98)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'food / 99.7-160.0', 'Class / 2'}), support=0.023092369477911646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 80.0-110.0', 'food / 99.7-160.0'}), confidence=0.11499999999999999, lift=3.9496551724137925), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'food / 99.7-160.0'}), items_add=frozenset({'Class / 2'}), confidence=0.793103448275862, lift=3.949655172413793)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'health / 101.2-150.4', 'Class / 2'}), support=0.03714859437751004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'health / 101.2-150.4'}), confidence=0.185, lift=3.020655737704918), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'health / 101.2-150.4'}), items_add=frozenset({'Class / 2'}), confidence=0.6065573770491803, lift=3.020655737704918)]),
#  RelationRecord(items=frozenset({'health / 150.4-199.6', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.0321285140562249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'health / 150.4-199.6'}), confidence=0.15999999999999998, lift=3.006792452830188), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'health / 150.4-199.6'}), items_add=frozenset({'Class / 2'}), confidence=0.6037735849056602, lift=3.006792452830188)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'health / 248.8-298.0', 'Class / 2'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2', 'health / 248.8-298.0'}), confidence=0.05025125628140704, lift=3.8500193274062626), OrderedStatistic(items_base=frozenset({'health / 248.8-298.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.7692307692307693, lift=3.8500193274062626)]),
#  RelationRecord(items=frozenset({'health / 51.754-101.2', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.014056224899598393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'health / 51.754-101.2', 'transportation / 49.85-80.0'}), confidence=0.06999999999999999, lift=3.32), OrderedStatistic(items_base=frozenset({'health / 51.754-101.2', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6666666666666667, lift=3.3200000000000003)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'health / 51.754-101.2', 'Class / 2'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 80.0-110.0', 'health / 51.754-101.2'}), confidence=0.060000000000000005, lift=3.1452631578947368), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'health / 51.754-101.2'}), items_add=frozenset({'Class / 2'}), confidence=0.631578947368421, lift=3.1452631578947368)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'housing / 400.401-520.8', 'Class / 2'}), confidence=0.05025125628140704, lift=3.5750179468772436), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.7142857142857143, lift=3.5750179468772436)]),
#  RelationRecord(items=frozenset({'housing / 520.8-640.6', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.01706827309236948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'housing / 520.8-640.6', 'Class / 2'}), confidence=0.08542713567839197, lift=3.038765254845657), OrderedStatistic(items_base=frozenset({'housing / 520.8-640.6', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.6071428571428572, lift=3.038765254845657)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'housing / 640.6-760.4', 'Class / 2'}), support=0.02710843373493976, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'housing / 640.6-760.4'}), confidence=0.135, lift=3.538421052631579), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'housing / 640.6-760.4'}), items_add=frozenset({'Class / 2'}), confidence=0.7105263157894737, lift=3.5384210526315787)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'housing / 640.6-760.4', 'Class / 2'}), support=0.02610441767068273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 80.0-110.0', 'housing / 640.6-760.4'}), confidence=0.13, lift=3.0111627906976746), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'housing / 640.6-760.4'}), items_add=frozenset({'Class / 2'}), confidence=0.6046511627906976, lift=3.011162790697674)]),
#  RelationRecord(items=frozenset({'housing / 760.4-880.2', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.03313253012048193, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'housing / 760.4-880.2', 'transportation / 49.85-80.0'}), confidence=0.165, lift=3.9128571428571433), OrderedStatistic(items_base=frozenset({'housing / 760.4-880.2', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.7857142857142858, lift=3.9128571428571433)]),
#  RelationRecord(items=frozenset({'housing / 880.2-1000.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.02610441767068273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'housing / 880.2-1000.0', 'transportation / 49.85-80.0'}), confidence=0.13, lift=3.082857142857143), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'housing / 880.2-1000.0', 'Class / 2'}), confidence=0.1306532663316583, lift=3.7180186647523334), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.7428571428571428, lift=3.718018664752333), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6190476190476191, lift=3.082857142857143)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.035140562248995984, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'income / 1334.0-1721.0', 'transportation / 49.85-80.0'}), confidence=0.175, lift=3.057894736842105), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6140350877192983, lift=3.057894736842105)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'income / 2108.0-2495.0', 'Class / 2'}), support=0.01104417670682731, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'income / 2108.0-2495.0', 'Class / 2'}), confidence=0.05527638190954774, lift=3.238545669524091), OrderedStatistic(items_base=frozenset({'income / 2108.0-2495.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.6470588235294118, lift=3.2385456695240915)]),
#  RelationRecord(items=frozenset({'income / 947.0-1334.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.03112449799196787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'income / 947.0-1334.0', 'Class / 2'}), confidence=0.15577889447236182, lift=3.1031155778894473), OrderedStatistic(items_base=frozenset({'income / 947.0-1334.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.62, lift=3.1031155778894473)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'non-essential / 231.355-361.0', 'Class / 2'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'non-essential / 231.355-361.0'}), confidence=0.05, lift=3.3200000000000003), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'non-essential / 231.355-361.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6666666666666666, lift=3.32)]),
#  RelationRecord(items=frozenset({'non-essential / 490.0-619.0', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.04618473895582329, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'non-essential / 490.0-619.0'}), confidence=0.22999999999999998, lift=3.0543999999999993), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2', 'non-essential / 490.0-619.0'}), confidence=0.23115577889447236, lift=3.0697487437185926), OrderedStatistic(items_base=frozenset({'non-essential / 490.0-619.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.6133333333333333, lift=3.069748743718593), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'non-essential / 490.0-619.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6133333333333333, lift=3.0544)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'non-essential / 619.0-748.0', 'Class / 2'}), support=0.020080321285140562, ordered_statistics=[OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2', 'non-essential / 619.0-748.0'}), confidence=0.10050251256281408, lift=3.033348560986752), OrderedStatistic(items_base=frozenset({'non-essential / 619.0-748.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.606060606060606, lift=3.033348560986752)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'university / 350.15-400.1', 'Class / 2'}), support=0.02710843373493976, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'university / 350.15-400.1'}), confidence=0.135, lift=3.3615000000000004), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'university / 350.15-400.1'}), items_add=frozenset({'Class / 2'}), confidence=0.675, lift=3.3615000000000004)]),
#  RelationRecord(items=frozenset({'university / 400.1-450.05', 'transportation / 49.85-80.0', 'Class / 2'}), support=0.02710843373493976, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'university / 400.1-450.05', 'transportation / 49.85-80.0'}), confidence=0.135, lift=3.2795121951219515), OrderedStatistic(items_base=frozenset({'university / 400.1-450.05', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6585365853658537, lift=3.2795121951219515)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'university / 450.05-500.0', 'Class / 2'}), support=0.02208835341365462, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0', 'university / 450.05-500.0'}), confidence=0.11, lift=3.0433333333333334), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 2', 'university / 450.05-500.0'}), confidence=0.11055276381909548, lift=3.4409547738693473), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'Class / 2'}), items_add=frozenset({'transportation / 49.85-80.0'}), confidence=0.6875000000000001, lift=3.4409547738693473), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 2'}), confidence=0.6111111111111112, lift=3.0433333333333334)]),
#  RelationRecord(items=frozenset({'food / 160.0-220.0', 'housing / 400.401-520.8', 'Class / 3'}), support=0.02108433734939759, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'food / 160.0-220.0'}), confidence=0.13043478260869562, lift=4.1907433380084145), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 3'}), confidence=0.6774193548387096, lift=4.1907433380084145)]),
#  RelationRecord(items=frozenset({'food / 160.0-220.0', 'housing / 520.8-640.6', 'Class / 3'}), support=0.01706827309236948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 520.8-640.6', 'food / 160.0-220.0'}), confidence=0.10559006211180123, lift=3.2864906832298137), OrderedStatistic(items_base=frozenset({'housing / 520.8-640.6', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 3'}), confidence=0.5312500000000001, lift=3.286490683229814)]),
#  RelationRecord(items=frozenset({'food / 160.0-220.0', 'transportation / 140.0-170.0', 'Class / 3'}), support=0.015060240963855422, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'transportation / 140.0-170.0', 'food / 160.0-220.0'}), confidence=0.09316770186335403, lift=3.199828657100021), OrderedStatistic(items_base=frozenset({'transportation / 140.0-170.0', 'food / 160.0-220.0'}), items_add=frozenset({'Class / 3'}), confidence=0.5172413793103448, lift=3.1998286571000207)]),
#  RelationRecord(items=frozenset({'food / 160.0-220.0', 'university / 250.0-300.2', 'Class / 3'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'food / 160.0-220.0'}), items_add=frozenset({'Class / 3', 'university / 250.0-300.2'}), confidence=0.055248618784530384, lift=3.0570902394106816), OrderedStatistic(items_base=frozenset({'university / 250.0-300.2', 'Class / 3'}), items_add=frozenset({'food / 160.0-220.0'}), confidence=0.5555555555555556, lift=3.057090239410681)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'health / 248.8-298.0', 'Class / 3'}), support=0.013052208835341365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'food / 99.7-160.0', 'health / 248.8-298.0'}), confidence=0.08074534161490682, lift=4.0211180124223596), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'health / 248.8-298.0'}), items_add=frozenset({'Class / 3'}), confidence=0.6499999999999999, lift=4.0211180124223596)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'housing / 400.401-520.8', 'Class / 3'}), support=0.03413654618473896, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'food / 99.7-160.0', 'housing / 400.401-520.8'}), confidence=0.21118012422360247, lift=5.007985803016859), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'housing / 400.401-520.8'}), items_add=frozenset({'Class / 3'}), confidence=0.8095238095238096, lift=5.007985803016859)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'housing / 520.8-640.6', 'Class / 3'}), support=0.01706827309236948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'food / 99.7-160.0', 'housing / 520.8-640.6'}), confidence=0.10559006211180123, lift=3.392506511721098), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'housing / 520.8-640.6'}), items_add=frozenset({'Class / 3'}), confidence=0.5483870967741936, lift=3.392506511721098)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0', 'Class / 3'}), support=0.025100401606425703, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0'}), confidence=0.15527950310559005, lift=3.290603938152504), OrderedStatistic(items_base=frozenset({'food / 99.7-160.0', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 3'}), confidence=0.5319148936170213, lift=3.290603938152504)]),
#  RelationRecord(items=frozenset({'food / 99.7-160.0', 'university / 450.05-500.0', 'Class / 3'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'food / 99.7-160.0'}), items_add=frozenset({'Class / 3', 'university / 450.05-500.0'}), confidence=0.04950495049504951, lift=3.081683168316832), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'Class / 3'}), items_add=frozenset({'food / 99.7-160.0'}), confidence=0.625, lift=3.0816831683168315)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'health / 248.8-298.0', 'Class / 3'}), support=0.01104417670682731, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'health / 248.8-298.0'}), confidence=0.06832298136645962, lift=3.402484472049689), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'health / 248.8-298.0'}), items_add=frozenset({'Class / 3'}), confidence=0.55, lift=3.4024844720496894)]),
#  RelationRecord(items=frozenset({'housing / 640.6-760.4', 'health / 248.8-298.0', 'Class / 3'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'health / 248.8-298.0'}), items_add=frozenset({'housing / 640.6-760.4', 'Class / 3'}), confidence=0.09900990099009901, lift=3.400477978832366), OrderedStatistic(items_base=frozenset({'housing / 640.6-760.4', 'Class / 3'}), items_add=frozenset({'health / 248.8-298.0'}), confidence=0.3448275862068965, lift=3.400477978832366)]),
#  RelationRecord(items=frozenset({'transportation / 140.0-170.0', 'health / 248.8-298.0', 'Class / 3'}), support=0.014056224899598393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'transportation / 140.0-170.0', 'health / 248.8-298.0'}), confidence=0.08695652173913043, lift=3.6086956521739126), OrderedStatistic(items_base=frozenset({'transportation / 140.0-170.0', 'health / 248.8-298.0'}), items_add=frozenset({'Class / 3'}), confidence=0.5833333333333333, lift=3.608695652173912)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'transportation / 140.0-170.0', 'Class / 3'}), support=0.03112449799196787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'transportation / 140.0-170.0'}), confidence=0.19254658385093165, lift=3.5514147688060724), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'transportation / 140.0-170.0'}), items_add=frozenset({'Class / 3'}), confidence=0.5740740740740741, lift=3.551414768806073)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'transportation / 170.0-200.0', 'Class / 3'}), support=0.029116465863453816, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'transportation / 170.0-200.0'}), confidence=0.18012422360248448, lift=4.271517302573204), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'transportation / 170.0-200.0'}), items_add=frozenset({'Class / 3'}), confidence=0.6904761904761906, lift=4.271517302573203)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'university / 350.15-400.1', 'Class / 3'}), support=0.024096385542168676, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'university / 350.15-400.1'}), confidence=0.14906832298136646, lift=3.093167701863354), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'university / 350.15-400.1'}), items_add=frozenset({'Class / 3'}), confidence=0.5, lift=3.093167701863354)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'university / 400.1-450.05', 'Class / 3'}), support=0.023092369477911646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8', 'university / 400.1-450.05'}), confidence=0.14285714285714285, lift=3.1619047619047618), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'university / 400.1-450.05'}), items_add=frozenset({'Class / 3'}), confidence=0.5111111111111111, lift=3.1619047619047613)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'university / 450.05-500.0', 'Class / 3'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8'}), items_add=frozenset({'Class / 3', 'university / 450.05-500.0'}), confidence=0.05309734513274337, lift=3.305309734513275), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'Class / 3'}), items_add=frozenset({'housing / 400.401-520.8'}), confidence=0.7500000000000001, lift=3.305309734513275)]),
#  RelationRecord(items=frozenset({'food / 220.0-280.0', 'Class / 4', 'university / 250.0-300.2'}), support=0.015060240963855422, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'food / 220.0-280.0', 'university / 250.0-300.2'}), confidence=0.11363636363636363, lift=3.7727272727272725), OrderedStatistic(items_base=frozenset({'food / 220.0-280.0', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.5, lift=3.7727272727272725)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'Class / 4', 'food / 280.0-340.0'}), support=0.024096385542168676, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'food / 280.0-340.0'}), confidence=0.18181818181818182, lift=3.9367588932806328), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 4'}), confidence=0.5217391304347827, lift=3.9367588932806328)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'Class / 4', 'food / 280.0-340.0'}), support=0.018072289156626505, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'transportation / 49.85-80.0', 'food / 280.0-340.0'}), confidence=0.13636363636363635, lift=3.086776859504132), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 4'}), confidence=0.40909090909090906, lift=3.086776859504132)]),
#  RelationRecord(items=frozenset({'university / 250.0-300.2', 'Class / 4', 'food / 280.0-340.0'}), support=0.020080321285140562, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'food / 280.0-340.0', 'university / 250.0-300.2'}), confidence=0.1515151515151515, lift=3.509513742071881), OrderedStatistic(items_base=frozenset({'university / 250.0-300.2', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 4'}), confidence=0.46511627906976744, lift=3.5095137420718814)]),
#  RelationRecord(items=frozenset({'university / 300.2-350.15', 'Class / 4', 'food / 280.0-340.0'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'university / 300.2-350.15', 'food / 280.0-340.0'}), confidence=0.12121212121212119, lift=3.0181818181818176), OrderedStatistic(items_base=frozenset({'university / 300.2-350.15', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 4'}), confidence=0.39999999999999997, lift=3.0181818181818176)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'food / 340.0-400.0', 'Class / 4'}), support=0.03815261044176707, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'food / 340.0-400.0'}), confidence=0.2878787878787879, lift=4.778787878787879), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8'}), items_add=frozenset({'food / 340.0-400.0', 'Class / 4'}), confidence=0.168141592920354, lift=3.3493805309734515), OrderedStatistic(items_base=frozenset({'food / 340.0-400.0', 'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8'}), confidence=0.76, lift=3.3493805309734515), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'food / 340.0-400.0'}), items_add=frozenset({'Class / 4'}), confidence=0.6333333333333334, lift=4.778787878787879)]),
#  RelationRecord(items=frozenset({'food / 340.0-400.0', 'Class / 4', 'university / 250.0-300.2'}), support=0.019076305220883535, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'food / 340.0-400.0', 'university / 250.0-300.2'}), confidence=0.14393939393939395, lift=3.050290135396519), OrderedStatistic(items_base=frozenset({'food / 340.0-400.0', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.4042553191489362, lift=3.0502901353965184)]),
#  RelationRecord(items=frozenset({'university / 300.2-350.15', 'food / 340.0-400.0', 'Class / 4'}), support=0.02208835341365462, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'food / 340.0-400.0', 'university / 300.2-350.15'}), confidence=0.16666666666666666, lift=3.7727272727272725), OrderedStatistic(items_base=frozenset({'food / 340.0-400.0', 'university / 300.2-350.15'}), items_add=frozenset({'Class / 4'}), confidence=0.5, lift=3.7727272727272725)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'Class / 4', 'health / 150.4-199.6'}), support=0.023092369477911646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'health / 150.4-199.6'}), confidence=0.17424242424242423, lift=3.044657097288676), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'health / 150.4-199.6'}), items_add=frozenset({'Class / 4'}), confidence=0.4035087719298246, lift=3.044657097288676)]),
#  RelationRecord(items=frozenset({'health / 199.6-248.8', 'Class / 4', 'university / 250.0-300.2'}), support=0.019076305220883535, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'health / 199.6-248.8', 'university / 250.0-300.2'}), confidence=0.14393939393939395, lift=3.050290135396519), OrderedStatistic(items_base=frozenset({'university / 250.0-300.2'}), items_add=frozenset({'health / 199.6-248.8', 'Class / 4'}), confidence=0.10270270270270271, lift=3.0085850556438793), OrderedStatistic(items_base=frozenset({'health / 199.6-248.8', 'Class / 4'}), items_add=frozenset({'university / 250.0-300.2'}), confidence=0.5588235294117647, lift=3.0085850556438793), OrderedStatistic(items_base=frozenset({'health / 199.6-248.8', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.4042553191489362, lift=3.0502901353965184)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'Class / 4', 'income / 1721.0-2108.0'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8'}), items_add=frozenset({'Class / 4', 'income / 1721.0-2108.0'}), confidence=0.07079646017699115, lift=3.3577749683944376), OrderedStatistic(items_base=frozenset({'Class / 4', 'income / 1721.0-2108.0'}), items_add=frozenset({'housing / 400.401-520.8'}), confidence=0.7619047619047619, lift=3.3577749683944376)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'income / 2108.0-2495.0', 'Class / 4'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'income / 2108.0-2495.0'}), confidence=0.07575757575757575, lift=3.2806324110671934), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'income / 2108.0-2495.0'}), items_add=frozenset({'Class / 4'}), confidence=0.43478260869565216, lift=3.2806324110671934)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'income / 947.0-1334.0', 'Class / 4'}), support=0.02208835341365462, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'income / 947.0-1334.0'}), confidence=0.16666666666666666, lift=3.2549019607843137), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'income / 947.0-1334.0'}), items_add=frozenset({'Class / 4'}), confidence=0.43137254901960786, lift=3.2549019607843137)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'transportation / 49.85-80.0', 'Class / 4'}), support=0.024096385542168676, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'transportation / 49.85-80.0'}), confidence=0.18181818181818182, lift=4.311688311688312), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'transportation / 49.85-80.0'}), items_add=frozenset({'Class / 4'}), confidence=0.5714285714285715, lift=4.311688311688312)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'housing / 400.401-520.8', 'Class / 4'}), support=0.024096385542168676, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'transportation / 80.0-110.0', 'housing / 400.401-520.8'}), confidence=0.18181818181818182, lift=4.024242424242424), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'housing / 400.401-520.8'}), items_add=frozenset({'Class / 4'}), confidence=0.5333333333333333, lift=4.0242424242424235)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'Class / 4', 'university / 250.0-300.2'}), support=0.0321285140562249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'university / 250.0-300.2'}), confidence=0.24242424242424238, lift=6.3540669856459315), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.8421052631578946, lift=6.3540669856459315)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'university / 300.2-350.15', 'Class / 4'}), support=0.0321285140562249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8', 'university / 300.2-350.15'}), confidence=0.24242424242424238, lift=4.471380471380471), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'university / 300.2-350.15'}), items_add=frozenset({'Class / 4'}), confidence=0.5925925925925926, lift=4.471380471380471)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'university / 350.15-400.1', 'Class / 4'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8'}), items_add=frozenset({'Class / 4', 'university / 350.15-400.1'}), confidence=0.07079646017699115, lift=3.5256637168141594), OrderedStatistic(items_base=frozenset({'university / 350.15-400.1', 'Class / 4'}), items_add=frozenset({'housing / 400.401-520.8'}), confidence=0.7999999999999999, lift=3.5256637168141594)]),
#  RelationRecord(items=frozenset({'housing / 520.8-640.6', 'Class / 4', 'university / 250.0-300.2'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 520.8-640.6', 'university / 250.0-300.2'}), confidence=0.12121212121212119, lift=4.311688311688311), OrderedStatistic(items_base=frozenset({'housing / 520.8-640.6', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.5714285714285714, lift=4.311688311688311)]),
#  RelationRecord(items=frozenset({'housing / 520.8-640.6', 'university / 300.2-350.15', 'Class / 4'}), support=0.013052208835341365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'housing / 520.8-640.6', 'university / 300.2-350.15'}), confidence=0.09848484848484847, lift=3.1642228739002927), OrderedStatistic(items_base=frozenset({'housing / 520.8-640.6', 'university / 300.2-350.15'}), items_add=frozenset({'Class / 4'}), confidence=0.41935483870967744, lift=3.164222873900293)]),
#  RelationRecord(items=frozenset({'university / 250.0-300.2', 'Class / 4', 'housing / 640.6-760.4'}), support=0.01104417670682731, ordered_statistics=[OrderedStatistic(items_base=frozenset({'university / 250.0-300.2'}), items_add=frozenset({'Class / 4', 'housing / 640.6-760.4'}), confidence=0.059459459459459456, lift=4.23011583011583), OrderedStatistic(items_base=frozenset({'Class / 4', 'housing / 640.6-760.4'}), items_add=frozenset({'university / 250.0-300.2'}), confidence=0.7857142857142858, lift=4.230115830115831)]),
#  RelationRecord(items=frozenset({'university / 250.0-300.2', 'Class / 4', 'income / 1721.0-2108.0'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'university / 250.0-300.2'}), items_add=frozenset({'Class / 4', 'income / 1721.0-2108.0'}), confidence=0.06486486486486487, lift=3.076447876447877), OrderedStatistic(items_base=frozenset({'Class / 4', 'income / 1721.0-2108.0'}), items_add=frozenset({'university / 250.0-300.2'}), confidence=0.5714285714285715, lift=3.076447876447877)]),
#  RelationRecord(items=frozenset({'transportation / 49.85-80.0', 'Class / 4', 'university / 250.0-300.2'}), support=0.018072289156626505, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'transportation / 49.85-80.0', 'university / 250.0-300.2'}), confidence=0.13636363636363635, lift=3.086776859504132), OrderedStatistic(items_base=frozenset({'transportation / 49.85-80.0', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.40909090909090906, lift=3.086776859504132)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'Class / 4', 'university / 250.0-300.2'}), support=0.020080321285140562, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'transportation / 80.0-110.0', 'university / 250.0-300.2'}), confidence=0.1515151515151515, lift=3.509513742071881), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 250.0-300.2'}), items_add=frozenset({'Class / 4'}), confidence=0.46511627906976744, lift=3.5095137420718814)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'university / 300.2-350.15', 'Class / 4'}), support=0.013052208835341365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 4'}), items_add=frozenset({'transportation / 80.0-110.0', 'university / 300.2-350.15'}), confidence=0.09848484848484847, lift=3.0653409090909087), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 300.2-350.15'}), items_add=frozenset({'Class / 4'}), confidence=0.40625, lift=3.0653409090909087)]),
#  RelationRecord(items=frozenset({'Class / 5', 'housing / 880.2-1000.0', 'food / 280.0-340.0'}), support=0.0321285140562249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 5'}), items_add=frozenset({'housing / 880.2-1000.0', 'food / 280.0-340.0'}), confidence=0.21768707482993194, lift=4.81814058956916), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0'}), items_add=frozenset({'Class / 5', 'food / 280.0-340.0'}), confidence=0.1807909604519774, lift=3.1046171829339566), OrderedStatistic(items_base=frozenset({'Class / 5', 'food / 280.0-340.0'}), items_add=frozenset({'housing / 880.2-1000.0'}), confidence=0.5517241379310344, lift=3.104617182933956), OrderedStatistic(items_base=frozenset({'housing / 880.2-1000.0', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 5'}), confidence=0.711111111111111, lift=4.81814058956916)]),
#  RelationRecord(items=frozenset({'Class / 5', 'university / 250.0-300.2', 'food / 280.0-340.0'}), support=0.023092369477911646, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 5'}), items_add=frozenset({'food / 280.0-340.0', 'university / 250.0-300.2'}), confidence=0.15646258503401358, lift=3.6241101091599424), OrderedStatistic(items_base=frozenset({'university / 250.0-300.2', 'food / 280.0-340.0'}), items_add=frozenset({'Class / 5'}), confidence=0.5348837209302325, lift=3.624110109159943)]),
# ...
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'housing / 520.8-640.6', 'non-essential / 619.0-748.0'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'housing / 520.8-640.6', 'non-essential / 619.0-748.0'}), confidence=0.14925373134328357, lift=3.811710677382319), OrderedStatistic(items_base=frozenset({'housing / 520.8-640.6', 'non-essential / 619.0-748.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.2564102564102564, lift=3.811710677382319)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'housing / 640.6-760.4', 'university / 450.05-500.0'}), support=0.01104417670682731, ordered_statistics=[OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'housing / 640.6-760.4', 'university / 450.05-500.0'}), confidence=0.16417910447761194, lift=3.0281923714759533), OrderedStatistic(items_base=frozenset({'housing / 640.6-760.4', 'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.2037037037037037, lift=3.0281923714759533)]),
#  RelationRecord(items=frozenset({'Class / 6', 'university / 450.05-500.0', 'housing / 640.6-760.4', 'non-essential / 490.0-619.0'}), support=0.014056224899598393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'housing / 640.6-760.4', 'non-essential / 490.0-619.0'}), confidence=0.06763285024154589, lift=3.207729468599034), OrderedStatistic(items_base=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), items_add=frozenset({'housing / 640.6-760.4', 'university / 450.05-500.0'}), confidence=0.1728395061728395, lift=3.1879286694101507), OrderedStatistic(items_base=frozenset({'housing / 640.6-760.4', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), confidence=0.25925925925925924, lift=3.1879286694101507), OrderedStatistic(items_base=frozenset({'Class / 6', 'housing / 640.6-760.4', 'non-essential / 490.0-619.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.6666666666666667, lift=3.2077294685990343)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'non-essential / 361.0-490.0', 'university / 450.05-500.0'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'income / 1334.0-1721.0', 'non-essential / 361.0-490.0', 'university / 450.05-500.0'}), confidence=0.05882352941176471, lift=3.08359133126935), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'non-essential / 361.0-490.0'}), confidence=0.057971014492753624, lift=3.0389016018306636), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'non-essential / 361.0-490.0', 'university / 450.05-500.0'}), confidence=0.1791044776119403, lift=3.2434192672998643), OrderedStatistic(items_base=frozenset({'Class / 6', 'non-essential / 361.0-490.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'university / 450.05-500.0'}), confidence=0.2727272727272727, lift=3.7727272727272725), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'non-essential / 361.0-490.0'}), confidence=0.16666666666666669, lift=3.772727272727273), OrderedStatistic(items_base=frozenset({'non-essential / 361.0-490.0', 'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.2181818181818182, lift=3.2434192672998643), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'non-essential / 361.0-490.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.631578947368421, lift=3.0389016018306636), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'non-essential / 361.0-490.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6'}), confidence=0.631578947368421, lift=3.08359133126935)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), support=0.015060240963855422, ordered_statistics=[OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'non-essential / 490.0-619.0'}), confidence=0.07246376811594203, lift=4.009661835748792), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'non-essential / 490.0-619.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.8333333333333334, lift=4.009661835748792)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'university / 450.05-500.0', 'non-essential / 619.0-748.0'}), support=0.013052208835341365, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'income / 1334.0-1721.0', 'non-essential / 619.0-748.0', 'university / 450.05-500.0'}), confidence=0.06372549019607843, lift=3.73356401384083), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'non-essential / 619.0-748.0', 'university / 450.05-500.0'}), confidence=0.19402985074626863, lift=4.831343283582089), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'non-essential / 619.0-748.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.32499999999999996, lift=4.831343283582089), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'university / 450.05-500.0', 'non-essential / 619.0-748.0'}), items_add=frozenset({'Class / 6'}), confidence=0.7647058823529411, lift=3.73356401384083)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 140.0-170.0', 'university / 450.05-500.0'}), support=0.01104417670682731, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'income / 1334.0-1721.0', 'transportation / 140.0-170.0', 'university / 450.05-500.0'}), confidence=0.05392156862745098, lift=3.1591695501730106), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 140.0-170.0'}), confidence=0.05314009661835749, lift=3.528502415458937), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'transportation / 140.0-170.0', 'university / 450.05-500.0'}), confidence=0.16417910447761194, lift=4.54228855721393), OrderedStatistic(items_base=frozenset({'Class / 6', 'transportation / 140.0-170.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'university / 450.05-500.0'}), confidence=0.275, lift=3.804166666666667), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'transportation / 140.0-170.0'}), confidence=0.1527777777777778, lift=3.804166666666667), OrderedStatistic(items_base=frozenset({'transportation / 140.0-170.0', 'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.3055555555555556, lift=4.54228855721393), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 140.0-170.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.7333333333333334, lift=3.5285024154589375), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'transportation / 140.0-170.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6'}), confidence=0.6470588235294118, lift=3.1591695501730106)]),
#  RelationRecord(items=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 80.0-110.0', 'university / 450.05-500.0'}), support=0.010040160642570281, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'income / 1334.0-1721.0', 'transportation / 80.0-110.0', 'university / 450.05-500.0'}), confidence=0.049019607843137254, lift=4.068627450980392), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 80.0-110.0'}), confidence=0.04830917874396135, lift=3.0072463768115942), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), items_add=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), confidence=0.14925373134328357, lift=3.033810539141029), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), items_add=frozenset({'income / 1334.0-1721.0', 'Class / 6'}), confidence=0.20408163265306123, lift=3.0338105391410295), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'Class / 6', 'transportation / 80.0-110.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.625, lift=3.0072463768115942), OrderedStatistic(items_base=frozenset({'income / 1334.0-1721.0', 'transportation / 80.0-110.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6'}), confidence=0.8333333333333333, lift=4.068627450980392)]),
#  RelationRecord(items=frozenset({'Class / 6', 'non-essential / 490.0-619.0', 'university / 450.05-500.0', 'income / 1721.0-2108.0'}), support=0.018072289156626505, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6', 'income / 1721.0-2108.0'}), items_add=frozenset({'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), confidence=0.29508196721311475, lift=3.093701466781708), OrderedStatistic(items_base=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), items_add=frozenset({'income / 1721.0-2108.0', 'university / 450.05-500.0'}), confidence=0.2222222222222222, lift=3.8830409356725144), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'income / 1721.0-2108.0'}), items_add=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), confidence=0.3157894736842105, lift=3.8830409356725144), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), items_add=frozenset({'Class / 6', 'income / 1721.0-2108.0'}), confidence=0.1894736842105263, lift=3.093701466781708)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'university / 450.05-500.0', 'income / 1721.0-2108.0'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'transportation / 80.0-110.0', 'income / 1721.0-2108.0', 'university / 450.05-500.0'}), confidence=0.05882352941176471, lift=3.254901960784314), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'income / 1721.0-2108.0'}), confidence=0.057971014492753624, lift=3.8492753623188407), OrderedStatistic(items_base=frozenset({'Class / 6', 'income / 1721.0-2108.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), confidence=0.19672131147540986, lift=3.998661759785882), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'Class / 6'}), items_add=frozenset({'income / 1721.0-2108.0', 'university / 450.05-500.0'}), confidence=0.24489795918367346, lift=4.279269602577873), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'income / 1721.0-2108.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'Class / 6'}), confidence=0.2105263157894737, lift=4.279269602577873), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'income / 1721.0-2108.0'}), confidence=0.24489795918367346, lift=3.9986617597858816), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'income / 1721.0-2108.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.8, lift=3.8492753623188407), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0', 'income / 1721.0-2108.0'}), items_add=frozenset({'Class / 6'}), confidence=0.6666666666666667, lift=3.254901960784314)]),
#  RelationRecord(items=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), support=0.01606425702811245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Class / 6'}), items_add=frozenset({'transportation / 80.0-110.0', 'non-essential / 490.0-619.0', 'university / 450.05-500.0'}), confidence=0.0784313725490196, lift=3.550802139037433), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'non-essential / 490.0-619.0'}), confidence=0.07729468599033816, lift=4.051868802440884), OrderedStatistic(items_base=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), confidence=0.19753086419753085, lift=4.0151171579743), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'Class / 6'}), items_add=frozenset({'non-essential / 490.0-619.0', 'university / 450.05-500.0'}), confidence=0.32653061224489793, lift=3.423415682062298), OrderedStatistic(items_base=frozenset({'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), items_add=frozenset({'transportation / 80.0-110.0', 'Class / 6'}), confidence=0.16842105263157892, lift=3.423415682062298), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0'}), items_add=frozenset({'Class / 6', 'non-essential / 490.0-619.0'}), confidence=0.32653061224489793, lift=4.0151171579743), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'Class / 6', 'non-essential / 490.0-619.0'}), items_add=frozenset({'university / 450.05-500.0'}), confidence=0.8421052631578946, lift=4.051868802440884), OrderedStatistic(items_base=frozenset({'transportation / 80.0-110.0', 'university / 450.05-500.0', 'non-essential / 490.0-619.0'}), items_add=frozenset({'Class / 6'}), confidence=0.7272727272727272, lift=3.5508021390374327)]),
#  RelationRecord(items=frozenset({'housing / 400.401-520.8', 'food / 340.0-400.0', 'university / 300.2-350.15', 'non-essential / 490.0-619.0'}), support=0.012048192771084338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'food / 340.0-400.0', 'university / 300.2-350.15'}), items_add=frozenset({'housing / 400.401-520.8', 'non-essential / 490.0-619.0'}), confidence=0.2727272727272727, lift=3.086776859504132), OrderedStatistic(items_base=frozenset({'housing / 400.401-520.8', 'non-essential / 490.0-619.0'}), items_add=frozenset({'food / 340.0-400.0', 'university / 300.2-350.15'}), confidence=0.13636363636363635, lift=3.086776859504132)])]

# %%
def inspect(results):
    lhs = []
    rhs = []
    supports = []
    confidences = []
    lifts = [] 

    for result in results:
        lhs_items = tuple(result[2][0][0])      
        rhs_item = tuple(result[2][0][1])
        lhs.append(lhs_items)
        rhs.append(rhs_item)
        supports.append(result[1])
        confidences.append(result[2][0][2])
        lifts.append(result[2][0][3])

    return list(zip(lhs, rhs, supports, confidences, lifts))

resultsinDataFrame = pd.DataFrame(inspect(results), columns=["LeftHand", "RightHand", "Support", "Confidence", "Lift"])
resultsinDataFrame.to_csv("association_rules.csv", index=False)

resultsinDataFrame = resultsinDataFrame[
    resultsinDataFrame['LeftHand'].apply(
        lambda x: isinstance(x, tuple) and len(x) == 1 and 'Class / ' in x[0]
    )
]
resultsinDataFrame.to_csv("association_rules_class.csv", index=False)

# %% [markdown]
# # Assosation rules without Classes

# %%
df_t.drop(columns=["Class"], inplace=True)
df_t.head()
# Out:
#                  housing                food                transportation  \
# 0  housing / 640.6-760.4  food / 280.0-340.0  transportation / 110.0-140.0
# 1  housing / 520.8-640.6  food / 340.0-400.0   transportation / 80.0-110.0
# 2  housing / 640.6-760.4  food / 160.0-220.0  transportation / 110.0-140.0
# 3  housing / 640.6-760.4  food / 280.0-340.0  transportation / 110.0-140.0
# 4  housing / 760.4-880.2  food / 340.0-400.0  transportation / 140.0-170.0
#
#                    income                non-essential                health  \
# 0   income / 947.0-1334.0  non-essential / 361.0-490.0  health / 199.6-248.8
# 1  income / 1721.0-2108.0  non-essential / 619.0-748.0  health / 199.6-248.8
# 2  income / 1334.0-1721.0  non-essential / 490.0-619.0  health / 101.2-150.4
# 3  income / 558.065-947.0  non-essential / 490.0-619.0  health / 101.2-150.4
# 4   income / 947.0-1334.0  non-essential / 361.0-490.0  health / 101.2-150.4
#
#                   university
# 0  university / 450.05-500.0
# 1  university / 400.1-450.05
# 2   university / 250.0-300.2
# 3  university / 400.1-450.05
# 4  university / 300.2-350.15

# %%
transactions = df_t.values.tolist()
rules = apriori(transactions = transactions, min_support = 0.01, min_cinfidence = 0.2, min_lift = 3, min_length = 2, max_length = 4)
results = list(rules)

# %%
resultsinDataFrame = pd.DataFrame(inspect(results), columns=["LeftHand", "RightHand", "Support", "Confidence", "Lift"])

resultsinDataFrame.to_csv("association_rules_woclass.csv", index=False)
